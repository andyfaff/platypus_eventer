# %%
from quokka_process import process_file
from pathlib import Path

# %%
process_file(
    277015,               # number of NeXUS file
    25,                   # frame frequency (Hz)
    25,                   # How many frames does one oscillation of SE take?
    2.0,                  # subframe_bin_sz (ms), divides frame period into smaller sections, if you think you have faster kinetics
    50,                   # splits SE oscillation [0, 2 * pi] into this many datasets
    Path("277015_data/NEXUS"), # Path to NeXUS file
    Path("277015_data/NEF"),   # Path to NEF
    Path("277015_data/SEF")    # Path to SEF
)
# Out:
# Processing 277015_data/NEXUS/QKK0277015.nx.hdf, daq_dirname='DAQ_2025-08-07T16-14-30'
# Obtaining NEF/SEF and merging
# loading SEF
# array search: 34, nearest time: 33
# deglitching
# fitting sine wave
# offset=np.float64(1.635221940490843), amplitude=np.float64(0.9516217913647402), f0=np.float64(2.5489845362841086), osc_period=np.float64(25.000256804247655)
# loading NEF
# digitising frames
# binning neutrons
